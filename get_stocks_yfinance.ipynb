# %%
#Import Libraries
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as pyplot
import matplotlib.dates as mdates
# %matplotlib inline

import datetime as dt
import time

#The kicker:
import yfinance as yf

# %%
PATH = "/Users/aidanosullivan/Desktop/PythonFinance/Python4Finance"

# %% [markdown]
# # YFinance

# %%
def get_info_on_stocks(ticker):
    stock = yf.Ticker(ticker)
    hist = stock.history(period = "max")["Close"] #get max period 
    
    print(stock.financials)

# %%
# Start end date defaults
S_DATE = "2017-02-01"
E_DATE = "2022-12-06"
S_DATE_DT = pd.to_datetime(S_DATE)
E_DATE_DT = pd.to_datetime(E_DATE)
short_history = a.history(start = S_DATE_DT, end = E_DATE_DT)
# Out:
#                                        2021-10-31 2020-10-31 2019-10-31  \
# Research Development                     4.41e+08   3.97e+08   4.04e+08
# Effect Of Accounting Charges                 None       None       None
# Income Before Tax                        1.36e+09   8.42e+08   9.19e+08
# Minority Interest                             NaN        NaN        NaN
# Net Income                               1.21e+09   7.19e+08  1.071e+09
# Selling General Administrative          1.562e+09  1.395e+09  1.358e+09
# Gross Profit                            3.407e+09  2.837e+09  2.805e+09
# Ebit                                    1.404e+09  1.045e+09  1.043e+09
# Operating Income                        1.404e+09  1.045e+09  1.043e+09
# Other Operating Expenses                     None       None       None
# Interest Expense                         -8.1e+07   -7.8e+07   -7.4e+07
# Extraordinary Items                          None       None       None
# ...

# %%
print(short_history)
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2017-02-01   47.003271   47.848620   46.763115   47.320274  2244600
# 2017-02-02   46.955240   47.070514   46.561385   46.974453  1352200
# 2017-02-03   47.156973   47.522011   47.128156   47.435555  1191800
# 2017-02-06   47.195393   47.435549   47.032085   47.329880   952100
# 2017-02-07   47.473972   47.819797   47.320273   47.685310  2170700
# ...                ...         ...         ...         ...      ...
# 2022-02-07  141.500000  142.490005  139.809998  140.369995  1444100
# 2022-02-08  139.110001  141.410004  138.289993  140.809998  1515400
# 2022-02-09  142.729996  145.100006  142.149994  144.440002  1216900
# 2022-02-10  141.559998  144.039993  140.580002  141.660004  1063700
# 2022-02-11  141.119995  142.449997  136.300003  137.169998   621629
#
#             Dividends  Stock Splits
# Date
# 2017-02-01        0.0             0
# 2017-02-02        0.0             0
# ...

# %%
get_info_on_stocks('MSFT')
# Out:
# Date
# 2018-09-12    0.225
# 2018-09-13    0.295
# 2018-09-14    0.300
# 2018-09-17    0.430
# 2018-09-18    0.435
# Name: Close, dtype: float64

# %% [markdown]
# ## Hold Stocks Not Downloaded

# %%
stocks_not_downloaded = []
missing_stocks = []

# %% [markdown]
# ## Returns a named column data from a CSV

# %%
def get_column_from_csv(file, col_name):
    #Try to get the file and if it doesn't exist, issue a warning
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df[col_name]

# %% [markdown]
# ## Get Stock Tickers from CSV

# %%
tickers = get_column_from_csv(PATH + "/Wilshire-5000-Stocks.csv", "Ticker")

# %% [markdown]
# ## Save Stock Data to CSV

# %%
def save_to_csv_from_yahoo(folder, ticker):
    stock = yf.Ticker(ticker)
    try:
        print("Get Data for : ", ticker)
        df = stock.history(period = "max")
        time.sleep(2)
        if df.empty:
            stocks_not_downloaded.append(ticker)
        the_file = folder + ticker.replace(".", "_") + '.csv' #can't have any extra periods
        print(time, "Saved")
        df.to_csv(the_file)
    except Exception as ex:
        stocks_not_downloaded.append(ticker)
        print("Couldn't get data for : ", ticker)

# %% [markdown]
# ## Get 5 years of data for the 1st 20 stocks

# %%
folder = PATH + '/Wilshire_Stocks/'
for x in range(3001, 3500):
    save_to_csv_from_yahoo(folder, tickers[x])
print("Finished")
# Out:
# WNEB
# <module 'time' (built-in)> Saved
# Get Data for :  WOR
# <module 'time' (built-in)> Saved
# Get Data for :  WOW
# <module 'time' (built-in)> Saved
# Get Data for :  WPC
# <module 'time' (built-in)> Saved
# Get Data for :  WPG
# - WPG: No data found, symbol may be delisted
# <module 'time' (built-in)> Saved
# Get Data for :  WPX
# - WPX: No data found, symbol may be delisted
# <module 'time' (built-in)> Saved
# Get Data for :  WRB
# <module 'time' (built-in)> Saved
# Get Data for :  WRE
# <module 'time' (built-in)> Saved
# Get Data for :  WRI
# - WRI: No data found, symbol may be delisted
# <module 'time' (built-in)> Saved
# Get Data for :  WRK
# <module 'time' (built-in)> Saved
# Get Data for :  WRLD
# <module 'time' (built-in)> Saved
# Get Data for :  WRTC
# - WRTC: No data found, symbol may be delisted
# <module 'time' (built-in)> Saved
# Get Data for :  WSBC
# <module 'time' (built-in)> Saved
# Get Data for :  WSBF
# <module 'time' (built-in)> Saved
# Get Data for :  WSC
# ...

# %%
len(tickers)
# Out:
# 3481

# %%
A = yf.Ticker(tickers[0])
A.history(period = 'max')
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 1999-11-18   27.989303   30.757479   24.605981   27.066580  62546380
# 1999-11-19   26.412983   26.451431   24.490642   24.836664  15234146
# 1999-11-22   25.413365   27.066580   24.644428   27.066580   6577870
# 1999-11-23   26.143854   26.835898   24.605980   24.605980   5975611
# 1999-11-24   24.682880   25.797839   24.605985   25.259583   4843231
# ...                ...         ...         ...         ...       ...
# 2022-02-04  141.479996  142.350006  139.669998  141.119995   1087400
# 2022-02-07  141.500000  142.490005  139.809998  140.369995   1444100
# 2022-02-08  139.110001  141.410004  138.289993  140.809998   1515400
# 2022-02-09  142.729996  145.100006  142.149994  144.440002   1216900
# 2022-02-10  141.559998  144.039993  140.979996  141.225006    557890
#
#             Dividends  Stock Splits
# Date
# 1999-11-18        0.0           0.0
# 1999-11-19        0.0           0.0
# ...
