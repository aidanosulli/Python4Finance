# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

# pip install numpy
# conda install -c anaconda pandas
# conda install -c conda-forge matplotlib

import datetime as dt # For defining dates

import time

# In Powershell Prompt : conda install -c conda-forge multitasking
# pip install -i https://pypi.anaconda.org/ranaroussi/simple yfinance

import yfinance as yf

# To show all your output File -> Preferences -> Settings Search for Notebook
# Notebook Output Text Line Limit and set to 100

# Used for file handling like deleting files
import os

# conda install -c conda-forge cufflinks-py
# conda install -c plotly plotly
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

from plotly.subplots import make_subplots

# New Imports
# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

import warnings
warnings.simplefilter("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Constants

# %%
PATH = "/Users/aidanosullivan/Desktop/PythonFinance/Python4Finance"

# Start end date defaults
S_DATE = "2017-02-01"
E_DATE = "2022-12-06"
S_DATE_DT = pd.to_datetime(S_DATE)
E_DATE_DT = pd.to_datetime(E_DATE)

# %% [markdown]
# ## Get Column Data from CSV

# %%
def get_column_from_csv(file, col_name):
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df[col_name]

# %% [markdown]
# ## Get Stock Tickers

# %%
tickers = get_column_from_csv(PATH + "/Wilshire-5000-Stocks.csv", "Ticker")
print(len(tickers))
# Out:
# 3481

# %% [markdown]
# ## Save Stock Data to CSV

# %%
# Function that gets a dataframe by providing a ticker and starting date
def save_to_csv_from_yahoo(folder, ticker, period = "5y"):
    stock = yf.Ticker(ticker)
    
    try:
        print("Get Data for : ", ticker)
        # Get historical closing price data
        df = stock.history(period=period)
    
        # Wait 2 seconds
        time.sleep(2)
        
        # Remove the period for saving the file name
        # Save data to a CSV file
        # File to save to 
        the_file = folder + ticker.replace(".", "_") + '.csv'
        print(the_file, " Saved")
        df.to_csv(the_file)
    except Exception as ex:
        print("Couldn't Get Data for :", ticker)

# %% [markdown]
# ## Download All Stocks

# %%
folder = PATH + '/Wilshire_Stocks/'
for x in range(0, len(tickers)):
    save_to_csv_from_yahoo(folder, tickers[x])
    print("Finished")
# Out:
# ythonFinance/Python4Finance/Wilshire_Stocks/VSI.csv  Saved
# Finished
# Get Data for :  VSLR
# - VSLR: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/VSLR.csv  Saved
# Finished
# Get Data for :  VVUS
# - VVUS: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/VVUS.csv  Saved
# Finished
# Get Data for :  VMW
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/VMW.csv  Saved
# Finished
# Get Data for :  VCRA
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/VCRA.csv  Saved
# Finished
# Get Data for :  VNRX
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/VNRX.csv  Saved
# Finished
# Get Data for :  VISI
# - VISI: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/VISI.csv  Saved
# Finished
# Get Data for :  VG
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/VG.csv  Saved
# Finished
# Get Data for :  VNO
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/VNO.csv  Saved
# Finished
# Get Data for :  VOXX
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/VOXX.csv  Saved
# Finished
# Get Data for :  VOYA
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/VOYA.csv  Saved
# Finished
# Get Data for :  VYGR
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/VYGR.csv  Saved
# Finished
# Get Data for :  VSEC
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/VSEC.csv  Saved
# Finished
# Get Data for :  VTVT
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/VTVT.csv  Saved
# Finished
# Get Data for :  VMC
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/VMC.csv  Saved
# Finished
# Get Data for :  VUZI
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/VUZI.csv  Saved
# Finished
# Get Data for :  WTI
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WTI.csv  Saved
# Finished
# Get Data for :  WPC
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WPC.csv  Saved
# Finished
# Get Data for :  WRB
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WRB.csv  Saved
# Finished
# Get Data for :  GRA
# - GRA: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/GRA.csv  Saved
# Finished
# Get Data for :  GWW
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/GWW.csv  Saved
# Finished
# Get Data for :  WNC
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WNC.csv  Saved
# Finished
# Get Data for :  WBC
# - WBC: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WBC.csv  Saved
# Finished
# Get Data for :  WDR
# - WDR: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WDR.csv  Saved
# Finished
# Get Data for :  WTRH
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WTRH.csv  Saved
# Finished
# Get Data for :  WBA
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WBA.csv  Saved
# Finished
# Get Data for :  WD
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WD.csv  Saved
# Finished
# Get Data for :  WMT
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WMT.csv  Saved
# Finished
# Get Data for :  HCC
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/HCC.csv  Saved
# Finished
# Get Data for :  WAFD
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WAFD.csv  Saved
# Finished
# Get Data for :  WPG
# - WPG: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WPG.csv  Saved
# Finished
# Get Data for :  WRE
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WRE.csv  Saved
# Finished
# Get Data for :  WASH
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WASH.csv  Saved
# Finished
# Get Data for :  WM
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WM.csv  Saved
# Finished
# Get Data for :  WAT
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WAT.csv  Saved
# Finished
# Get Data for :  WSBF
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WSBF.csv  Saved
# Finished
# Get Data for :  WSO
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WSO.csv  Saved
# Finished
# Get Data for :  WTS
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WTS.csv  Saved
# Finished
# Get Data for :  WVE
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WVE.csv  Saved
# Finished
# Get Data for :  W
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/W.csv  Saved
# Finished
# Get Data for :  WSTG
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WSTG.csv  Saved
# Finished
# Get Data for :  WDFC
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WDFC.csv  Saved
# Finished
# Get Data for :  WBS
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WBS.csv  Saved
# Finished
# Get Data for :  WEC
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WEC.csv  Saved
# Finished
# Get Data for :  WRI
# - WRI: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WRI.csv  Saved
# Finished
# Get Data for :  WMK
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WMK.csv  Saved
# Finished
# Get Data for :  WBT
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WBT.csv  Saved
# Finished
# Get Data for :  WCG
# - WCG: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WCG.csv  Saved
# Finished
# Get Data for :  WEBK
# - WEBK: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WEBK.csv  Saved
# Finished
# Get Data for :  WFC
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WFC.csv  Saved
# Finished
# Get Data for :  WELL
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WELL.csv  Saved
# Finished
# Get Data for :  WERN
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WERN.csv  Saved
# Finished
# Get Data for :  WSBC
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WSBC.csv  Saved
# Finished
# Get Data for :  WAIR
# - WAIR: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WAIR.csv  Saved
# Finished
# Get Data for :  WCC
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WCC.csv  Saved
# Finished
# Get Data for :  WTBA
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WTBA.csv  Saved
# Finished
# Get Data for :  WST
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WST.csv  Saved
# Finished
# Get Data for :  WABC
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WABC.csv  Saved
# Finished
# Get Data for :  WSTL
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WSTL.csv  Saved
# Finished
# Get Data for :  WAL
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WAL.csv  Saved
# Finished
# Get Data for :  WMC
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WMC.csv  Saved
# Finished
# Get Data for :  WDC
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WDC.csv  Saved
# Finished
# Get Data for :  WNEB
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WNEB.csv  Saved
# Finished
# Get Data for :  WAB
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WAB.csv  Saved
# Finished
# Get Data for :  WLK
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WLK.csv  Saved
# Finished
# Get Data for :  WRK
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WRK.csv  Saved
# Finished
# Get Data for :  WWR
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WWR.csv  Saved
# Finished
# Get Data for :  WHG
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WHG.csv  Saved
# Finished
# Get Data for :  WEX
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WEX.csv  Saved
# Finished
# Get Data for :  WEYS
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WEYS.csv  Saved
# Finished
# Get Data for :  WY
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WY.csv  Saved
# Finished
# Get Data for :  WHLR
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WHLR.csv  Saved
# Finished
# Get Data for :  WHR
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WHR.csv  Saved
# Finished
# Get Data for :  WTM
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WTM.csv  Saved
# Finished
# Get Data for :  WSR
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WSR.csv  Saved
# Finished
# Get Data for :  WLL
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WLL.csv  Saved
# Finished
# Get Data for :  WOW
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WOW.csv  Saved
# Finished
# Get Data for :  WYY
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WYY.csv  Saved
# Finished
# Get Data for :  WHLM
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WHLM.csv  Saved
# Finished
# Get Data for :  WVVI
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WVVI.csv  Saved
# Finished
# Get Data for :  WLDN
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WLDN.csv  Saved
# Finished
# Get Data for :  WLH
# - WLH: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WLH.csv  Saved
# Finished
# Get Data for :  WSM
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WSM.csv  Saved
# Finished
# Get Data for :  WLFC
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WLFC.csv  Saved
# Finished
# Get Data for :  WLTW
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WLTW.csv  Saved
# Finished
# Get Data for :  WSC
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WSC.csv  Saved
# Finished
# Get Data for :  WING
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WING.csv  Saved
# Finished
# Get Data for :  WINA
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WINA.csv  Saved
# Finished
# Get Data for :  WGO
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WGO.csv  Saved
# Finished
# Get Data for :  WTFC
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WTFC.csv  Saved
# Finished
# Get Data for :  WTT
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WTT.csv  Saved
# Finished
# Get Data for :  WETF
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WETF.csv  Saved
# Finished
# Get Data for :  WWW
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WWW.csv  Saved
# Finished
# Get Data for :  WWD
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WWD.csv  Saved
# Finished
# Get Data for :  WDAY
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WDAY.csv  Saved
# Finished
# Get Data for :  WKHS
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WKHS.csv  Saved
# Finished
# Get Data for :  WK
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WK.csv  Saved
# Finished
# Get Data for :  WRLD
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WRLD.csv  Saved
# Finished
# Get Data for :  INT
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/INT.csv  Saved
# Finished
# Get Data for :  WWE
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WWE.csv  Saved
# Finished
# Get Data for :  WOR
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WOR.csv  Saved
# Finished
# Get Data for :  WPX
# - WPX: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WPX.csv  Saved
# Finished
# Get Data for :  WRTC
# - WRTC: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WRTC.csv  Saved
# Finished
# Get Data for :  WMGI
# - WMGI: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WMGI.csv  Saved
# Finished
# Get Data for :  WSFS
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WSFS.csv  Saved
# Finished
# Get Data for :  WVFC
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WVFC.csv  Saved
# Finished
# Get Data for :  WW
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WW.csv  Saved
# Finished
# Get Data for :  WYND
# - WYND: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WYND.csv  Saved
# Finished
# Get Data for :  WH
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WH.csv  Saved
# Finished
# Get Data for :  WYNN
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/WYNN.csv  Saved
# Finished
# Get Data for :  XFOR
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/XFOR.csv  Saved
# Finished
# Get Data for :  XBIT
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/XBIT.csv  Saved
# Finished
# Get Data for :  XELB
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/XELB.csv  Saved
# Finished
# Get Data for :  XEL
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/XEL.csv  Saved
# Finished
# Get Data for :  XNCR
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/XNCR.csv  Saved
# Finished
# Get Data for :  XHR
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/XHR.csv  Saved
# Finished
# Get Data for :  XERS
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/XERS.csv  Saved
# Finished
# Get Data for :  XRX
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/XRX.csv  Saved
# Finished
# Get Data for :  XLNX
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/XLNX.csv  Saved
# Finished
# Get Data for :  XOMA
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/XOMA.csv  Saved
# Finished
# Get Data for :  XPER
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/XPER.csv  Saved
# Finished
# Get Data for :  XPO
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/XPO.csv  Saved
# Finished
# Get Data for :  XSPA
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/XSPA.csv  Saved
# Finished
# Get Data for :  XTNT
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/XTNT.csv  Saved
# Finished
# Get Data for :  XYL
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/XYL.csv  Saved
# Finished
# Get Data for :  YELP
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/YELP.csv  Saved
# Finished
# Get Data for :  YETI
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/YETI.csv  Saved
# Finished
# Get Data for :  YEXT
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/YEXT.csv  Saved
# Finished
# Get Data for :  YTEN
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/YTEN.csv  Saved
# Finished
# Get Data for :  YMAB
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/YMAB.csv  Saved
# Finished
# Get Data for :  YORW
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/YORW.csv  Saved
# Finished
# Get Data for :  YRCW
# - YRCW: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/YRCW.csv  Saved
# Finished
# Get Data for :  YUM
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/YUM.csv  Saved
# Finished
# Get Data for :  YUMA
# - YUMA: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/YUMA.csv  Saved
# Finished
# Get Data for :  CTIB
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/CTIB.csv  Saved
# Finished
# Get Data for :  ZFGN
# - ZFGN: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZFGN.csv  Saved
# Finished
# Get Data for :  ZAGG
# - ZAGG: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZAGG.csv  Saved
# Finished
# Get Data for :  ZAYO
# - ZAYO: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZAYO.csv  Saved
# Finished
# Get Data for :  ZBRA
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZBRA.csv  Saved
# Finished
# Get Data for :  ZDGE
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZDGE.csv  Saved
# Finished
# Get Data for :  ZEN
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZEN.csv  Saved
# Finished
# Get Data for :  Z
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/Z.csv  Saved
# Finished
# Get Data for :  ZG
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZG.csv  Saved
# Finished
# Get Data for :  ZBH
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZBH.csv  Saved
# Finished
# Get Data for :  ZN
# - ZN: No data found, symbol may be delisted
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZN.csv  Saved
# Finished
# Get Data for :  ZION
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZION.csv  Saved
# Finished
# Get Data for :  ZIOP
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZIOP.csv  Saved
# Finished
# Get Data for :  ZIXI
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZIXI.csv  Saved
# Finished
# Get Data for :  ZTS
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZTS.csv  Saved
# Finished
# Get Data for :  ZGNX
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZGNX.csv  Saved
# Finished
# Get Data for :  ZM
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZM.csv  Saved
# Finished
# Get Data for :  ZSAN
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZSAN.csv  Saved
# Finished
# Get Data for :  ZVO
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZVO.csv  Saved
# Finished
# Get Data for :  ZS
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZS.csv  Saved
# Finished
# Get Data for :  ZUMZ
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZUMZ.csv  Saved
# Finished
# Get Data for :  ZUO
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZUO.csv  Saved
# Finished
# Get Data for :  ZYNE
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZYNE.csv  Saved
# Finished
# Get Data for :  ZYXI
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZYXI.csv  Saved
# Finished
# Get Data for :  ZNGA
# /Users/aidanosullivan/Desktop/PythonFinance/Python4Finance/Wilshire_Stocks/ZNGA.csv  Saved
# Finished
